# %%
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
#读数据

data_path = r".\MHcolors.csv"
data = pd.read_csv(data_path)
# with open(data_path, 'r') as file:
#     lines = file.readlines()
    
# data = {}
# current_color = None
# current_value = []
# # 解析每一行数据
# for line in lines:
#     line_data = line.strip().split('\t')  # 按制表符分割每一行数据
#     for item in line_data:
#         try:
#             value = float(item)
#             current_value.append(value)
#         except ValueError:
#             current_color = item
#             data[current_color] = current_value
data
# Out:
#            blue       green        red         hue         sat       value  \
# 0    158.573617   87.149159  12.927535  104.633626  233.911585  158.573617
# 1    154.006226   84.739667  11.923874  104.595441  235.135609  154.006226
# 2    139.289022   93.474136  27.855954  102.223655  203.665692  139.289022
# 3    133.784862   96.031360  32.069556  101.043149  193.662385  133.784862
# 4    147.222668   93.438442  21.047643  102.699370  218.257048  147.222668
# ..          ...         ...        ...         ...         ...         ...
# 843  174.672190  108.448678  23.381579  103.082281  220.672190  174.672190
# 844  178.635146  102.614578  14.431807  103.813358  234.164283  178.635146
# 845  181.909040   94.368501   8.601112  105.037635  242.669548  181.909040
# 846  182.535119   97.511441  11.099666  104.810353  239.307681  182.535119
# 847  179.549594   99.000429  14.521026  104.575153  234.153645  179.549594
#
#           HLS_H      HLS_L       HLS_S  label
# 0    104.623333  85.751006  216.888985  102.0
# 1    104.583228  82.966036  218.776488  102.0
# 2    102.215444  83.571713  170.448531  102.0
# 3    101.038068  82.926818  156.783826  102.0
# 4    102.685990  84.136061  191.892781  102.0
# ..          ...        ...         ...    ...
# 843  103.072419  99.028578  195.116369   99.8
# 844  103.805276  96.540571  217.394315   99.8
# 845  105.035498  95.284984  232.275471   99.8
# 846  104.809318  96.843469  226.213836   99.8
# 847  104.574074  97.049323  217.299542   99.8
#
# [848 rows x 10 columns]

# %%
# select_label = ['blue','green', 'hue', 'value', 'HLS_L', 'label']
# data = data[select_label]

# %%
data.describe()
# Out:
#              blue       green         red         hue         sat       value  \
# count  848.000000  848.000000  848.000000  848.000000  848.000000  848.000000
# mean   126.463104   31.248832    2.101850  115.224069  252.839969  126.466583
# std     52.978956   31.507689    3.962857    5.996943    5.589689   52.972907
# min     32.951236    0.094940    0.125395  101.043149  193.662385   33.802348
# 25%     69.921734    0.695813    0.430273  111.563371  253.954623   69.921734
# 50%    136.253378   25.056173    0.563340  114.575721  254.137416  136.253378
# 75%    171.764225   47.451156    1.682691  119.931969  254.235273  171.764225
# max    238.810860  116.573593   32.069556  138.903723  254.559970  238.810860
#
#             HLS_H       HLS_L       HLS_S       label
# count  848.000000  848.000000  848.000000  848.000000
# mean   115.220427   63.946874  250.991026   77.637736
# std      5.993383   26.950061    9.510228   12.129015
# min    101.038068   17.191772  156.783826    0.000000
# 25%    111.563676   35.093488  252.938182   68.600000
# 50%    114.568838   68.417595  253.337312   77.650000
# 75%    119.932221   86.377190  253.474718   84.600000
# max    138.883764  121.555777  254.131667  102.000000

# %%
#2、查看是否缺失数据
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 848 entries, 0 to 847
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   blue    848 non-null    float64
#  1   green   848 non-null    float64
#  2   red     848 non-null    float64
#  3   hue     848 non-null    float64
#  4   sat     848 non-null    float64
#  5   value   848 non-null    float64
#  6   HLS_H   848 non-null    float64
#  7   HLS_L   848 non-null    float64
#  8   HLS_S   848 non-null    float64
#  9   label   848 non-null    float64
# dtypes: float64(10)
# memory usage: 66.4 KB

# %%
#3、数据可视化，画出散点图
#先查看目标数据的分布
import seaborn as sns
outliers = ['label']

sns.boxplot(data = data[outliers])
plt.title("label Distribution")
plt.ylabel("Price Range")
plt.xlabel("Continuous Variable")
# Out:
# Text(0.5, 0, 'Continuous Variable')

# %%
ax=sns.pairplot(data)

# %%
#数据分割
np.random.seed(0)
from sklearn.model_selection import train_test_split
train, test = train_test_split(data, test_size = 0.3, random_state = 100)
train.shape
# Out:
# (593, 10)

# %%
# #对数据进行特征工程
# from sklearn.preprocessing import StandardScaler
# std = StandardScaler()
# train = std.fit_transform(train)
# train

# %%
# test = std.transform(test)
# test

# %%
#画出热力图
plt.figure(figsize = (22, 22))
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
sns.heatmap(train_df.corr(), cmap = "RdYlGn", xticklabels=train_df.columns,yticklabels=train_df.columns)
# Out:
# <AxesSubplot:>

# %%
#制作x，y

y_train = train[:, -1]
X_train = train[:, :-1]
y_test = test[:, -1]
X_test = test[:, :-1]
X_test
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8764\4086819265.py in <module>
#       1 #制作x，y
#       2
# ----> 3 y_train = train[:, -1]
#       4 X_train = train[:, :-1]
#       5 y_test = test[:, -1]
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), -1)' is an invalid key

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)

# %%
y_pre = model.predict(X_test)
y_pre

# %%
accuracy = model.score(X_test, y_test)
accuracy

# %%
y_pred = model.predict(X_test)
plt.scatter(y_test,y_pred , color='green')
plt.show()
print(accuracy)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("均方误差（MSE）: {:.2f}".format(mse))
print("决定系数（R^2）: {:.2f}".format(r2))

# %%
intercept = model.intercept_ 
coefficients = model.coef_ 
print("截距:", intercept) 
print("系数:", coefficients)
